# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn
import pandas as pd
from pandas import DataFrame, Series
# %matplotlib inline

# %%
batting_data = pd.read_csv('Data/core/Batting.csv', sep = ",", dtype = str, names = ['playerID', 'yearID', 'stint','teamID', 'IgID', 'G', 'AB', 'R', 'H' ,'2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB','SO', 'IBB', 'HBP', 'SH', 'SF', 'GIDP'])

# %%
batting_data.head()
# Out:
#     playerID  yearID  stint  teamID  IgID   G   AB   R   H  2B  ...   RBI  SB  \
# 0   playerID  yearID  stint  teamID  lgID   G   AB   R   H  2B  ...   RBI  SB
# 1  abercda01    1871      1     TRO   NaN   1    4   0   0   0  ...     0   0
# 2   addybo01    1871      1     RC1   NaN  25  118  30  32   6  ...    13   8
# 3  allisar01    1871      1     CL1   NaN  29  137  28  40   4  ...    19   3
# 4  allisdo01    1871      1     WS3   NaN  27  133  28  44  10  ...    27   1
#
#    CS  BB  SO  IBB  HBP   SH   SF  GIDP
# 0  CS  BB  SO  IBB  HBP   SH   SF  GIDP
# 1   0   0   0  NaN  NaN  NaN  NaN   NaN
# 2   1   4   0  NaN  NaN  NaN  NaN   NaN
# 3   1   2   5  NaN  NaN  NaN  NaN   NaN
# 4   1   0   2  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 22 columns]

# %%
salary_data = pd.read_csv('Data/core/Salaries.csv', sep = ",", dtype = str, names = ['yearID', 'teamID', 'IgID', 'playerID', 'salary'])

# %%
salary_data.head()
# Out:
#    yearID  teamID  IgID   playerID  salary
# 0  yearID  teamID  lgID   playerID  salary
# 1    1985     ATL    NL  barkele01  870000
# 2    1985     ATL    NL  bedrost01  550000
# 3    1985     ATL    NL  benedbr01  545000
# 4    1985     ATL    NL   campri01  633333

# %%
amalgamated_data = pd.merge(batting_data, salary_data)

# %%
amalgamated_data.head()
# Out:
#     playerID  yearID  stint  teamID  IgID   G   AB    R    H   2B   ...    \
# 0   playerID  yearID  stint  teamID  lgID   G   AB    R    H   2B   ...
# 1  ackerji01    1985      1     TOR    AL  61  NaN  NaN  NaN  NaN   ...
# 2  agostju01    1985      1     CHA    AL  54    0    0    0    0   ...
# 3  aguaylu01    1985      1     PHI    NL  91  165   27   46    7   ...
# 4  alexado01    1985      1     TOR    AL  36  NaN  NaN  NaN  NaN   ...
#
#     SB   CS   BB   SO  IBB  HBP   SH   SF  GIDP  salary
# 0   SB   CS   BB   SO  IBB  HBP   SH   SF  GIDP  salary
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  170000
# 2    0    0    0    0    0    0    0    0     0  147500
# 3    1    0   22   26    5    6    4    3     7  237000
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  875000
#
# [5 rows x 23 columns]

# %%
amalgamated_data['salary'].head()
# Out:
# 0    salary
# 1    170000
# 2    147500
# 3    237000
# 4    875000
# Name: salary, dtype: object
